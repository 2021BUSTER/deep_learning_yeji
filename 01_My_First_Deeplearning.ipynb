# %% [markdown]
# <a href="https://colab.research.google.com/github/2021BUSTER/deep_learning_yeji/blob/main/01_My_First_Deeplearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0
# -*- coding: utf-8 -*-
# 코드 내부에 한글을 사용가능 하게 해주는 부분입니다.

# 딥러닝을 구동하는 데 필요한 케라스 함수를 불러옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from google.colab import files
uploaded=files.upload()

# 필요한 라이브러리를 불러옵니다.
import numpy as np
import tensorflow as tf

# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분입니다.
np.random.seed(3)
tf.random.set_seed(3)

# 준비된 수술 환자 데이터를 불러들입니다.
Data_set = np.loadtxt("ThoraricSurgery.csv", delimiter=",")

# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장합니다.
X = Data_set[:,0:17]
Y = Data_set[:,17]

# 딥러닝 구조를 결정합니다(모델을 설정하고 실행하는 부분입니다).
model = Sequential()
model.add(Dense(30, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 딥러닝을 실행합니다.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=100, batch_size=10)
# Out:
# ...
#      <input type="file" id="files-6214d446-88d4-463c-8170-9075ef568503" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6214d446-88d4-463c-8170-9075ef568503">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ThoraricSurgery.csv to ThoraricSurgery.csv
# Train on 470 samples
# Epoch 1/100
# 470/470 [==============================] - 1s 2ms/sample - loss: 0.6902 - accuracy: 0.8106
# Epoch 2/100
# 470/470 [==============================] - 0s 213us/sample - loss: 0.4568 - accuracy: 0.8511
# Epoch 3/100
# 470/470 [==============================] - 0s 234us/sample - loss: 0.4714 - accuracy: 0.8447
# Epoch 4/100
# 470/470 [==============================] - 0s 266us/sample - loss: 0.4609 - accuracy: 0.8447
# Epoch 5/100
# ...
